# %% [markdown]
# <a href="https://colab.research.google.com/github/tharun786-mass/Data-analysis-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# x = 4
# x="Sally"
# x= 8
# print(x)

# %%
x = 5
y = "john"
x = 8
print(x)
# Out:
# 8

# %%
x = 5
y = "John"
print(type (x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = 4
A ="john"
print(x)
print(A)
# Out:
# 5
# john

# %%
x,y,z="orange","banana","cheery"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cheery

# %%
x = 5
y ="John"
print(x)
print(y)
# Out:
# 5
# John
